# %%
import numpy as np
import pandas as pd
import os
import re
from bs4 import BeautifulSoup

# %%
DATA_FOLDER = 'data/'
columns = ['web-scraper-order', 'text', 'section', 'topic', 'urls', 'userMentions', 'isReply', 'emojis']
distribution = {'bugreports': 9,
                'chat': 28,
                'collections': 8,
                'help': 31,
                'ligo': 5,
                'notes': 400,
                'science': 15,
                'virgo': 4}

# %%
def check_None(el):
    return el if el else None

def get_content(row):
    body = BeautifulSoup(row['body'], 'html.parser')
    content = body.find('div', {'class': 'talk-comment-content'})
    text_content = content.find('div', {'class':'markdown'})
    row['text'] = check_None(text_content.text)
    row['topic'] = row['links']
    row['urls'] = check_None(';'.join([a['href'] for a in content.findAll('a') if '.png' not in a['href']]))
    row['userMentions'] = check_None(';'.join(re.findall(r'\@\S+', row['text'])))
    row['isReply'] = check_None(body.find('div', {'class': 'talk-comment-reply'}) is not None)
    row['emojis'] = check_None(';'.join([img['alt'] for img in text_content.findAll('img', {'class': 'emoji'})]))
    return row

def get_comments_df(df):
    df = df.apply(get_content, axis=1)
    return df[columns]

def read_data(folder):
    comments_df = pd.DataFrame(columns=columns)
    for file in os.listdir(folder):
        df = pd.read_csv(os.path.join(folder, file))
        df['section'] = file.split('.')[0].split('[')[0]
        comments_df = comments_df.append(get_comments_df(df))
    return comments_df

# %%
# %%time
all_data = read_data(DATA_FOLDER)
all_data
# Out:
# Wall time: 7min 57s
#    web-scraper-order                                               text  \
# 0     1604198576-694  Hello - yes to the above suggestions. Please p...
# 1     1604198689-999  hey @team , why is there  audio in the field g...
# 2     1604198607-767  I should say, you have to be trying to go from...
# 3     1604198528-563  I believe that there are some problems at the ...
# 4    1604198895-1630  Thank you for flagging this and your construct...
# ..               ...                                                ...
# 14    1604198211-259  Scattered Light comes in many, many guises in ...
# 15    1604198222-261  For proposing new Virgo glitch classes, please...
# 16    1604198211-260  Horizontal lines at medium to high frequencies...
# 17    1604198211-257  On a related note, @dziakj1 has discovered (an...
# 18    1604198211-255  Hello,\nThis is amazing! Thank you so much for...
#
#        section                                              topic  \
# 0   bugreports  Emails from Zooniverse projects now fail to ar...
# 1   bugreports                               audio in field guide
# 2   bugreports                                     Frame 4 button
# 3   bugreports                              Possible level-up bug
# 4   bugreports                 Opting out of the level-up popups?
# ..         ...                                                ...
# 14       virgo              Virgo O3 glitch classes (placeholder)
# 15       virgo      Process for Making New Virgo Classes Official
# 16       virgo              Virgo O3 glitch classes (placeholder)
# 17       virgo              Virgo O3 glitch classes (placeholder)
# 18       virgo              Virgo O3 glitch classes (placeholder)
#
#                                                  urls userMentions isReply  \
# 0                       https://status.zooniverse.org         None    None
# 1                                                None        @team    None
# 2                                                None         None    None
# 3                                                None         None    None
# 4   https://github.com/zooniverse/Panoptes-Front-E...         None    None
# ..                                                ...          ...     ...
# 14  /projects/zooniverse/gravity-spy/talk/subjects...         None    True
# 15  https://www.zooniverse.org/projects/zooniverse...         None    None
# 16  /projects/zooniverse/gravity-spy/talk/subjects...         None    True
# 17  /projects/zooniverse/gravity-spy/talk/subjects...     @dziakj1    True
# 18                                               None         None    None
#
#    emojis
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 14   None
# 15   None
# 16   None
# 17   None
# 18   None
#
# [90501 rows x 8 columns]

# %%
print(np.unique(all_data['section'], return_counts=True))
print(all_data.isna().sum())
all_data.describe()
# Out:
# (array(['bugreports', 'chat', 'collections', 'help', 'ligo', 'notes',
#        'science', 'virgo'], dtype=object), array([  382,  1155,   339,  1348,   193, 86370,   695,    19],
#       dtype=int64))
# web-scraper-order        0
# text                     0
# section                  0
# topic                    0
# urls                 14974
# userMentions         86088
# isReply              85632
# emojis               88039
# dtype: int64
#        web-scraper-order    text section            topic  \
# count              90501   90501   90501            90501
# unique             90500   62865       8            54530
# top       1604684664-937  50sb\n   notes  Subject 3777930
# freq                   2     808   86370               36
#
#                                                      urls userMentions  \
# count                                               75527         4413
# unique                                              62938         1077
# top     /projects/zooniverse/gravity-spy/talk/tags/pos...  @EcceruElme
# freq                                                  508         1166
#
#        isReply emojis
# count     4869   2462
# unique       1    147
# top       True      😀
# freq      4869    918

# %%
def get_sample_df():
    return pd.concat([all_data[all_data['section'] == k].sample(v, random_state=42) for k, v in distribution.items()]).reset_index(drop=True)

# %%
sample_df = get_sample_df()
sample_df
# Out:
#     web-scraper-order                                               text  \
# 0      1604198662-928                         Hi did you fix this bug?\n
# 1     1604198796-1345  I have never been  quite certain that the X ax...
# 2     1604198776-1275  \nBecause I can understand it is of immense in...
# 3     1604198884-1593  And working again.\n(A Schrödinger tool, as we...
# 4       1604197902-62  I did occasionally. Reloading the site helps t...
# ..                ...                                                ...
# 495   1604199043-1992  Yep -- this is a really interesting trigger! V...
# 496    1604198211-254  We've seen many pretty moiré artefacts from LI...
# 497    1604198190-241  Hello,\nSimilar to what we have observed for 2...
# 498    1604198211-253  Thick (for a Q45 feature) braids at 19Hz, some...
# 499    1604198190-239  \nProposed name: viola\nID of proposer: @Eccer...
#
#         section                                              topic  \
# 0    bugreports                                   Subject 11057234
# 1    bugreports   RFE: An easy way to read off feature frequencies
# 2    bugreports   Statistics not updating on Gravity Spy home page
# 3    bugreports                             Gravity Spy Tools down
# 4    bugreports                       Already Seen keeps coming up
# ..          ...                                                ...
# 495     science  Read the press release about latest #Gravitati...
# 496       virgo              Virgo O3 glitch classes (placeholder)
# 497       virgo                                Viola - Virgo (O2a)
# 498       virgo              Virgo O3 glitch classes (placeholder)
# 499       virgo                                Viola - Virgo (O2a)
#
#                                                   urls  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                        /users/eperozzi;/users/sbc538
# ..                                                 ...
# 495                                               None
# 496  /projects/zooniverse/gravity-spy/talk/subjects...
# 497  https://www.zooniverse.org/projects/zooniverse...
# 498  /projects/zooniverse/gravity-spy/talk/subjects...
# 499  /projects/zooniverse/gravity-spy/talk/subjects...
#
#                            userMentions isReply emojis
# 0                                  None    True   None
# 1                                  None    None   None
# 2                                  None    True      😦
# 3                                  None    None      😃
# 4                     @eperozzi;@sbc538    None   None
# ..                                  ...     ...    ...
# 495                                None    True   None
# 496                                None    True   None
# 497                                None    None   None
# 498                        @PepBlanquer    True   None
# 499  @EcceruElme;@BLGoodwin;@moderators    None   None
#
# [500 rows x 8 columns]

# %%
print(np.unique(sample_df['section'], return_counts=True))
print(sample_df.isna().sum())
sample_df.describe()
# Out:
# (array(['bugreports', 'chat', 'collections', 'help', 'ligo', 'notes',
#        'science', 'virgo'], dtype=object), array([  9,  28,   8,  31,   5, 400,  15,   4], dtype=int64))
# web-scraper-order      0
# text                   0
# section                0
# topic                  0
# urls                 110
# userMentions         461
# isReply              452
# emojis               480
# dtype: int64
#        web-scraper-order               text section            topic  \
# count                500                500     500              500
# unique               500                474       8              485
# top      1604576473-5338  #repeatingblips\n   notes  Pulsar glitches
# freq                   1                  4     400                3
#
#                      urls userMentions isReply emojis
# count                 390           39      48     20
# unique                372           27       1      9
# top     /users/EcceruElme  @EcceruElme    True      😃
# freq                    6            9      48      7

# %%
all_data.to_csv(os.path.join(DATA_FOLDER, 'all_data.csv'), index=False)
sample_df.to_csv(os.path.join(DATA_FOLDER, 'sample.csv'), index=False)

# %%
all_data = pd.read_csv(os.path.join(DATA_FOLDER, 'all_data.csv'))
sample_df = pd.read_csv(os.path.join(DATA_FOLDER, 'sample.csv'))
difference_df = pd.concat([all_data, sample_df]).drop_duplicates(keep=False)
print(sample_df.shape, difference_df.shape)
# Out:
# (500, 8) (90001, 8)

# %%
difference_df.to_csv(os.path.join(DATA_FOLDER, 'difference.csv'), index=False)

# %%
all_data[all_data['web-scraper-order'] == '1604200055-3004']
# Out:
#      web-scraper-order         text section                 topic  \
# 1991   1604200055-3004  10070989 \n    help  Sub-spectrogram wave
#
#                                                    urls userMentions isReply  \
# 1991  /projects/zooniverse/gravity-spy/talk/subjects...          NaN     NaN
#
#      emojis
# 1991      😎
